# %% [markdown]
# # Google login
#
# https://console.cloud.google.com/auth/overview?authuser=2&organizationId=0&project=bike-setup-tracker-508807

# %% [markdown]
# # Datenbank / User
#
# https://supabase.com/dashboard/project/dcrkfiooddkbzljibomo

# %% [markdown]
# # Emails / Accounts erstellen (später)
#
# https://resend.com/emails
